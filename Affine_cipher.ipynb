# %%
class SravneniyeError(Exception):
    pass

# %%
class ReverseElementError(Exception):
    pass

# %% [markdown]
# Вычисление НОДа двух чисел

# %%
def extended_gcd(a, b):  
    if b == 0:  
        return a, 1, 0  
    else:  
        gcd, x1, y1 = extended_gcd(b, a % b)  
        x = y1  
        y = x1 - (a // b) * y1  
        return gcd, x, y

# %%
extended_gcd(7, 4)
# Out:
# (1, -1, 2)

# %% [markdown]
# Поиск обратного числа

# %%
def reverse_value(a, m, func):
    NOD, u, _ = func(a, m)
    if(NOD == 1):
        return u%m
    else:
        raise ReverseElementError()

# %% [markdown]
# Решение сравнения

# %%
def sravneniye(a, b, m, NOD_func, Obratnoye_func):
    if(b % NOD_func(a,m)[0] != 0):
        raise SravneniyeError()
    else:
        NOD = NOD_func(a,m)[0]
        a //= NOD
        b //= NOD
        m //= NOD

        x = (b * Obratnoye_func(a, m, NOD_func))%m

        lst = [m * i + x for i in range(NOD)]

        return lst

# %%
sravneniye(9, 6, 12, extended_gcd, reverse_value)
# Out:
# [2, 6, 10]

# %% [markdown]
# Решение системы сравнений

# %%
def systema_sravneniy(a1, a2, b1, b2, m, NOD_func, Obratnoye_func):
    return [(x, (b1 - a1*x)%m) for x in sravneniye(a1-a2, b1-b2, m, NOD_func, Obratnoye_func)]

# %%
systema_sravneniy(3, 7, 5, 1, 8, extended_gcd, reverse_value)
# Out:
# [(1, 2), (3, 4), (5, 6), (7, 0)]

# %% [markdown]
# Кодирование аффинным шифром

# %%
symbols = ['а','б','в','г','д','е','ж','з','и','й','к','л','м','н','о','п','р','с','т','у','ф','х','ц','ч','ш','щ','ъ','ы','ь','э','ю','я']

# %%
def crypt(a, b, alfavit ,str_):
    return "".join([alfavit[(a*alfavit.index(x)+b)%len(alfavit)] for x in str_])

# %% [markdown]
# Декодирование аффинным шифром

# %%
def decrypt(a, b, alfavit ,str_):
    return "".join([alfavit[(alfavit.index(y)-b)*a%len(alfavit)] for y in str_])

# %% [markdown]
# Создаём массив с более вероятными двумя буквами

# %%
veroyatnosti = {'о':0.09, 'е':0.072, 'а':0.062, 'и':0.062, 'т':0.053, 'н':0.053, 'с':0.045, 'р':0.04, 'в':0.038, 'л':0.035, 'к':0.028,'м':0.026, 'д':0.025, 'п':0.023, 'у':0.021, 'я':0.018, 'ы':0.016, 'з':0.016, 'ъ':0.014, 'ь':0.014, 'б':0.014, 'г':0.013, 'ч':0.012, 'й':0.01, 'х':0.009, 'ж':0.007, 'ю':0.006, 'ш':0.006, 'ц':0.004, 'щ':0.003, 'э':0.003, 'ф':0.002}

# %%
dict = {}
keys_list = list(veroyatnosti.keys())
for i in range(len(keys_list)):
    for j in range(i+1, len(keys_list)):
            
            dict[(symbols.index(keys_list[i]), symbols.index(keys_list[j]))] = veroyatnosti[keys_list[i]] + veroyatnosti[keys_list[j]]

# %%
sorted_pairs = sorted(dict.keys(), key=lambda pair: dict[pair], reverse=True)

# %%
sorted_pairs
# Out:
# [(14, 5),
#  (14, 0),
#  (14, 8),
#  (14, 18),
#  (14, 13),
#  (14, 17),
#  (5, 0),
#  (5, 8),
#  (14, 16),
#  (14, 2),
#  (14, 11),
#  (5, 18),
#  (5, 13),
#  (0, 8),
#  (14, 10),
#  (5, 17),
#  (14, 12),
#  (14, 4),
#  (0, 18),
#  (0, 13),
#  (8, 18),
#  (8, 13),
#  (14, 15),
#  (5, 16),
#  (14, 19),
#  (5, 2),
#  (14, 31),
#  (5, 11),
#  (0, 17),
#  (8, 17),
#  (14, 27),
#  (14, 7),
#  (18, 13),
#  (14, 26),
#  (14, 28),
#  (14, 1),
#  (14, 3),
#  (0, 16),
#  (8, 16),
#  (14, 23),
#  (0, 2),
#  (8, 2),
#  (14, 9),
#  (5, 10),
#  (14, 21),
#  (18, 17),
#  (13, 17),
#  (5, 12),
#  (14, 6),
#  (5, 4),
#  (0, 11),
#  (8, 11),
#  (14, 30),
#  (14, 24),
#  (5, 15),
#  (14, 22),
#  (14, 25),
#  (14, 29),
#  (5, 19),
#  (18, 16),
#  (13, 16),
#  (14, 20),
#  (18, 2),
#  (13, 2),
#  (5, 31),
#  (0, 10),
#  (8, 10),
#  (5, 27),
#  (5, 7),
#  (0, 12),
#  (8, 12),
#  (18, 11),
#  (13, 11),
#  (0, 4),
#  (8, 4),
#  (5, 26),
#  (5, 28),
#  (5, 1),
#  (5, 3),
#  (0, 15),
#  (8, 15),
# ...

# %% [markdown]
# Этот список даст нам вохможность получать наиболее вероятные ключи.

# %%
def change(str_, dict_):
    new_str = ""
    for i in str_:
        if(i in dict_.keys()):
            new_str += dict_[i]
        else:
            new_str += i
    return new_str

# %%
-11%33
# Out:
# 22

# %%
while(True):
    res1 = input("Если нужно проверить арифметику нажмите 1, взлом - 2, выход - 3")
    if(res1 == "1"):
        while(True):
            res = input("Вычисление НОД с коэффициентами Безу - 1, поиск обратного - 2, решение сравнения - 3, решение системы сравнений - 4, назад - 5")
            if(res == "1"):
                try:
                    a = int(input("Введите a"))
                    b = int(input("Введите b"))
                    r = extended_gcd(a, b)
                    print(f"НОД = {r[0]}, Коэффициенты Безу: {r[1]} и {r[2]}", flush=True)
                except Exception:
                    print("Вы ввели не целое число!", flush=True)
            elif(res == "2"):
                try:
                    a = int(input("Введите a"))
                    m = int(input("Введите m (модуль)"))
                    r = reverse_value(a, m, extended_gcd)
                    print(f"Обратный элемент = {r}", flush=True)
                except ReverseElementError:
                    print("Обратного элемента не существует!", flush=True)
                except Exception:
                    print("Вы ввели не число!", flush=True)
            elif(res == "3"):
                try:
                    a = int(input("Введите a"))
                    b = int(input("Введите b"))
                    m = int(input("Введите m (модуль)"))
                    r = sravneniye(a, b, m, extended_gcd, reverse_value)
                    if(len(r) > 1):
                        print(f"Решения сравнения: {r}", flush=True)
                    else:
                        print(f"Решение сравнения: x = {r[0]}", flush=True)
                except SravneniyeError:
                    print("Решения сравнения не существует!", flush=True)
                except ReverseElementError:
                    print("Решения сравнения не существует! В процессе решения сравнения не был найден обратный элемент!", flush=True)
                except Exception:
                    print("Вы ввели не число!", flush=True)
            elif(res == "4"):
                try:
                    a1 = int(input("Введите a1"))
                    a2 = int(input("Введите a2"))
                    b1 = int(input("Введите b1"))
                    b2 = int(input("Введите b2"))
                    m = int(input("Введите m (модуль)"))
                    r = systema_sravneniy(a1, a2, b1, b2, m, extended_gcd, reverse_value)
                    if(len(r) > 1):
                        print(f"Решения системы сравнений (первое число в скобках - х, второе - у): {r}", flush=True)
                    else:
                        print(f"Решение системы сравнений (первое число в скобках - х, второе - у): (x,y) = {r[0]}", flush=True)
                except SravneniyeError:
                    print("Решения системы сравнений не существует!", flush=True)
                except ReverseElementError:
                    print("Решения системы сравнений не существует! В процессе решения системы сравнений не был найден обратный элемент!", flush=True)
                except Exception:
                    print("Вы ввели не число!", flush=True)
            elif(res == "5"):
                break
    elif(res1 == "2"):
        is_found = False
        res = input("Введите зашифрованное сообщение: ")
        dict_ = {}
        while(True):
            answ = input("Введите 1, если хотите получить частотный анализ; введите 2, если хотите дешифровать; введите 3, чтобы выйти в главное меню")

            for i in res:
                if(i in list(dict_.keys())):
                    dict_[i] += 1
                else:
                    dict_[i] = 1
            two_most_popular = sorted(dict_.keys(), key=lambda pair: dict_[pair], reverse=True)[:2]

            if(answ == "1"):
                print(f"Самые популярные буквы: {two_most_popular}", flush=True)

            if(answ == "2"):
                for pair in sorted_pairs:
                    if(is_found == True):
                        break
                    try:
                        results = systema_sravneniy(pair[0], pair[1], symbols.index(two_most_popular[0]), symbols.index(two_most_popular[1]), len(symbols), extended_gcd, reverse_value)
                        print(f"При изменении буквы {symbols[pair[0]]} на {two_most_popular[0]} и {symbols[pair[1]]} на {two_most_popular[1]} получаем ключи (первое число a, второе число b) {results}", flush=True)
                        for result in results:
                            if(is_found == True):
                                break
                            try:
                                print(f"Ключ: {result}", flush=True)
                                print(decrypt(reverse_value(result[0], len(symbols), extended_gcd), result[1], symbols, res), flush=True)
                                answer = str(input("Корректно ли сообщение? (если корректно введите 'да')")).lower()
                                if(answer == "да"):
                                    is_found = True
                            except ReverseElementError:
                                print("На каком-то шаге нет обратного элемента!", flush=True)
                                continue
                            except Exception:
                                print(f"Что-то странное...", flush=True)
                                continue
                    except ReverseElementError:
                        print("На каком-то шаге нет обратного элемента!", flush=True)
                    except SravneniyeError:
                        print(f"Сравнение для пары {pair} не разрешимо!", flush=True)
                    except:
                        print(f"Что-то странное...", flush=True)

                    if(is_found == True):
                        break
                    
                    # тут просто меняются местами буквы (вероятности для такой пары одинаковы!)

                    print("Меняем местами буквы", flush=True)
                    try:
                        results = systema_sravneniy(pair[1], pair[0], symbols.index(two_most_popular[0]), symbols.index(two_most_popular[1]), len(symbols), extended_gcd, reverse_value)
                        print(f"При изменении буквы {symbols[pair[1]]} на {two_most_popular[0]} и {symbols[pair[0]]} на {two_most_popular[1]} получаем ключи (первое число a, второе число b) {results}", flush=True)
                        for result in results:
                            if(is_found == True):
                                break
                            try:
                                print(f"Ключ: {result}", flush=True)
                                print(decrypt(reverse_value(result[0], len(symbols), extended_gcd), result[1], symbols, res), flush=True)
                                answer = str(input("Корректно ли сообщение? (если корректно введите 'да')")).lower()
                                if(answer == "да"):
                                    is_found = True
                            except ReverseElementError:
                                print("На каком-то шаге нет обратного элемента!", flush=True)
                                continue
                            except Exception:
                                print(f"Что-то странное...", flush=True)
                                continue
                    except ReverseElementError:
                        print("На каком-то шаге нет обратного элемента!", flush=True)
                    except SravneniyeError:
                        print(f"Сравнение для пары {pair} не разрешимо!", flush=True)
                    except:
                        print(f"Что-то странное...", flush=True)
            if(answ == "3"):
                break
    elif(res1 =="3"):
        break
# Out:
# Самые популярные буквы: ['а', 'т']

# %% [markdown]
# ШТ:щковмтчгфюсякяфртичгфдесявжтрдясзруярдэсчфбефючхрэръвжмвгячхбрйебэчфчфгстнгюамвмякуежюутвщжнбеъкгфнчдщтндвсэчфкфмкукфмвежвэвссолкмгкжкфявруэеймчдфеэебчдмтвгяромеъвмч

# %% [markdown]
# ОТ: зимакрестьянинторжествуянадровняхобновляетпутьеголошадкаснегпочуплететсярысьюкакнибудьбраздыпушистыевзрываялетиткибиткаудалаяямщиксидитнаоблучкевтулупевкрасномкушаке

# %% [markdown]
# Евгений Онегин (Пушкин)

# %% [markdown]
# ключ: (17, 2)

# %% [markdown]
# ньжсфпншсавъужвлвъньиясрпзхшискнньядгшъхпхгпхсэйэвншхпхцгвянузнсозжмвлвъъвзгвшээвхрпжснньщзэвчуэсфясгъсглсгвшщцявлуфсяшзтмсисниясэсщдлъзъпцсмсг

# %% [markdown]
# тыбогатяоченьбедентыпрозаикяпоэттырумянкакмаковцветякаксмертьитощибледеннеимеяввекзаботтыживешьвогромномдомеяжсредьгоряихлопотпровожуднинасолом
